# %%
import pandas as pd

# Carregue seu arquivo
df = pd.read_pickle("data_strava_activities.pkl")

# %%
df['type'] = df['type'].apply(lambda x: x.root)

# %%
df = df.loc[df['type'] == 'Run'].copy()

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
# Extract components
df['year']  = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day']   = df['date'].dt.day
df['hour']  = df['date'].dt.hour
df['min']   = df['date'].dt.minute

# %%
df['weekday_num'] = df['date'].dt.weekday

# %%
df['weekday_name'] = df['date'].dt.day_name()

# %%
df['month_name'] = df['date'].dt.month_name()

# %%
df
# Out:
#               id                                  name  \
# 0    16889053929                    Longao pós rodízio
# 1    16849340824                 Corrida ao entardecer
# 2    16824842626  Retomando os treinos mais puxados :e
# 3    16807182821                 Corrida ao entardecer
# 4    16717511921                 Corrida ao entardecer
# ..           ...                                   ...
# 132   4116749876                 Corrida ao entardecer
# 134   4107947944                 Corrida ao entardecer
# 135   4098813894                    Corrida vespertina
# 136   4089786819                    Corrida vespertina
# 137   4084908411                 Corrida ao entardecer
#
#                          date type  distance  moving_time  average_speed  \
# 0   2025-12-30 19:45:47+00:00  Run   10502.1         3949          2.659
# 1   2025-12-26 20:10:21+00:00  Run    6012.6         1992          3.018
# 2   2025-12-23 20:45:47+00:00  Run    5002.0         1632          3.065
# 3   2025-12-21 20:59:05+00:00  Run    5667.3         2052          2.762
# 4   2025-12-11 19:38:15+00:00  Run    5009.4         1709          2.931
# ..                        ...  ...       ...          ...            ...
# 132 2020-09-26 19:52:35+00:00  Run    5988.1         2430          2.464
# 134 2020-09-24 18:16:31+00:00  Run    5003.3         1633          3.064
# 135 2020-09-22 17:46:24+00:00  Run      46.7           27          1.730
# 136 2020-09-20 17:18:16+00:00  Run    6033.5         2009          3.003
# 137 2020-09-19 20:59:54+00:00  Run    6175.3         2415          2.557
#
#      distance_km  pace_min_km  year  month  day  hour  min  weekday_num  \
# 0        10.5021     6.267001  2025     12   30    19   45            1
# 1         6.0126     5.521738  2025     12   26    20   10            4
# 2         5.0020     5.437825  2025     12   23    20   45            1
# 3         5.6673     6.034620  2025     12   21    20   59            6
# 4         5.0094     5.685977  2025     12   11    19   38            3
# ..           ...          ...   ...    ...  ...   ...  ...          ...
# 132       5.9881     6.763414  2020      9   26    19   52            5
# 134       5.0033     5.439743  2020      9   24    18   16            3
# 135       0.0467     9.635974  2020      9   22    17   46            1
# 136       6.0335     5.549570  2020      9   20    17   18            6
# 137       6.1753     6.517902  2020      9   19    20   59            5
#
#     weekday_name month_name
# 0        Tuesday   December
# 1         Friday   December
# 2        Tuesday   December
# 3         Sunday   December
# 4       Thursday   December
# ..           ...        ...
# 132     Saturday  September
# 134     Thursday  September
# 135      Tuesday  September
# 136       Sunday  September
# 137     Saturday  September
#
# [130 rows x 17 columns]

# %%
# Converta para JSON (orientado a registros é o mais fácil para JS)
# Salve dentro da pasta 'static/data/' do seu projeto Hugo
df.to_json("running_data.json", orient="records", date_format="iso")
